# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("benchmark.csv")
df
# Out:
#         m     p  speedup_arraycache  speedup_splay  speedup_presplay
# 0       1  0.50            1.190831       0.367803          1.281876
# 1       1  0.52            1.386362       0.376919          1.459367
# 2       1  0.54            1.235535       0.460855          1.422746
# 3       1  0.56            1.297526       0.327316          1.451537
# 4       1  0.58            1.343023       0.462295          1.372880
# ...   ...   ...                 ...            ...               ...
# 1295  491  0.92            0.818746       0.606219          2.078436
# 1296  491  0.94            0.791468       0.589058          2.145603
# 1297  491  0.96            0.898965       0.656360          2.078055
# 1298  491  0.98            0.765825       0.643390          2.393033
# 1299  491  1.00            0.977446       0.691458          2.328726
#
# [1300 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.m, df.p, c=df.speedup_splay, cmap="RdBu_r", vmin=0, vmax=2)
plt.colorbar()
plt.title("Splay tree speedup")
plt.xlabel("m (number of more frequently accessed elements)")
plt.ylabel("p (access frequency)")
# Out:
# Text(0, 0.5, 'p (access frequency)')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.m, df.p, c=df.speedup_arraycache, cmap="RdBu_r", vmin=0, vmax=2)
plt.colorbar()
plt.title("BST with cache speedup")
plt.xlabel("m (number of more frequently accessed elements)")
plt.ylabel("p (access frequency)")
# Out:
# Text(0, 0.5, 'p (access frequency)')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.m, df.p, c=df.speedup_presplay, cmap="RdBu_r", vmin=0, vmax=2)
plt.colorbar()
plt.title("Pre-splay speedup")
plt.xlabel("m (number of more frequently accessed elements)")
plt.ylabel("p (access frequency)")
# Out:
# Text(0, 0.5, 'p (access frequency)')
