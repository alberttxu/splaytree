# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("benchmark.csv")
df
# Out:
#        m      p  speedup_arraycache  speedup_splay
# 0      1  0.500            1.223861       0.263776
# 1      1  0.525            1.549997       0.316599
# 2      1  0.550            1.509507       0.304656
# 3      1  0.575            1.397466       0.317759
# 4      1  0.600            1.326111       0.300316
# ...   ..    ...                 ...            ...
# 1024  49  0.900            1.486066       0.456265
# 1025  49  0.925            1.590649       0.512594
# 1026  49  0.950            1.819648       0.526150
# 1027  49  0.975            1.828397       0.576567
# 1028  49  1.000            2.042722       0.623138
#
# [1029 rows x 4 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.m, df.p, c=df.speedup_splay, cmap="RdBu_r", vmin=0, vmax=2)
plt.colorbar()
plt.title("Splay tree vs BST speedup")
plt.xlabel("m (number of more frequently accessed elements)")
plt.ylabel("p (access frequency)")
# Out:
# Text(0, 0.5, 'p (access frequency)')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df.m, df.p, c=df.speedup_arraycache, cmap="RdBu_r", vmin=0, vmax=2)
plt.colorbar()
plt.title("BST with cache vs BST speedup")
plt.xlabel("m (number of more frequently accessed elements)")
plt.ylabel("p (access frequency)")
# Out:
# Text(0, 0.5, 'p (access frequency)')
